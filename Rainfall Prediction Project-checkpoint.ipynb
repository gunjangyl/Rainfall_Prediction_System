# %%
#Import Essential Libraries
import numpy as np
import pandas as pd

# %%
#Import dataset #df-dataframe
df=pd.read_csv("dataset.csv")
df.head()
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
#To print the dimension of dataframe
df.shape
# Out:
# (1461, 6)

# %%
#To print information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1461 non-null   object
#  1   precipitation  1461 non-null   float64
#  2   temp_max       1461 non-null   float64
#  3   temp_min       1461 non-null   float64
#  4   wind           1461 non-null   float64
#  5   weather        1461 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 68.6+ KB

# %%
#Drop the 'date' column from the dataframe
df2=df.drop("date",axis=1)
df2.head()
# Out:
#    precipitation  temp_max  temp_min  wind  weather
# 0            0.0      12.8       5.0   4.7  drizzle
# 1           10.9      10.6       2.8   4.5     rain
# 2            0.8      11.7       7.2   2.3     rain
# 3           20.3      12.2       5.6   4.7     rain
# 4            1.3       8.9       2.8   6.1     rain

# %%
#Separate datset into independent & dependent variables
X=df2.iloc[:,:4].values

# %%
y=df2.iloc[:,4].values

# %%
X
# Out:
# array([[ 0. , 12.8,  5. ,  4.7],
#        [10.9, 10.6,  2.8,  4.5],
#        [ 0.8, 11.7,  7.2,  2.3],
#        ...,
#        [ 0. ,  7.2,  0.6,  2.6],
#        [ 0. ,  5.6, -1. ,  3.4],
#        [ 0. ,  5.6, -2.1,  3.5]])

# %%
y
# Out:
# array(['drizzle', 'rain', 'rain', ..., 'fog', 'sun', 'sun'], dtype=object)

# %%
#Train-test split
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.1, random_state=2)

# %%
#Model Training
#Logistic Regression
from sklearn.linear_model import LogisticRegression
#Creating object of logistic regression
lg=LogisticRegression()
lg.fit(X_train,y_train)
#IGNORE THE WARNING
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
#Printing the values
y_test
# Out:
# array(['rain', 'snow', 'sun', 'sun', 'rain', 'rain', 'sun', 'rain', 'sun',
#        'rain', 'sun', 'rain', 'rain', 'fog', 'sun', 'rain', 'rain', 'sun',
#        'rain', 'sun', 'rain', 'drizzle', 'rain', 'sun', 'snow', 'rain',
#        'rain', 'rain', 'sun', 'rain', 'rain', 'rain', 'rain', 'rain',
#        'sun', 'sun', 'rain', 'rain', 'rain', 'drizzle', 'rain', 'rain',
#        'rain', 'snow', 'rain', 'rain', 'sun', 'sun', 'rain', 'rain',
#        'rain', 'rain', 'rain', 'drizzle', 'fog', 'snow', 'rain', 'sun',
#        'rain', 'sun', 'sun', 'rain', 'drizzle', 'rain', 'rain', 'sun',
#        'sun', 'rain', 'rain', 'rain', 'rain', 'sun', 'sun', 'sun', 'sun',
#        'sun', 'rain', 'sun', 'rain', 'rain', 'rain', 'sun', 'fog', 'snow',
#        'rain', 'sun', 'sun', 'sun', 'rain', 'rain', 'sun', 'rain', 'rain',
#        'sun', 'fog', 'sun', 'rain', 'rain', 'sun', 'sun', 'rain', 'rain',
#        'rain', 'rain', 'sun', 'sun', 'sun', 'rain', 'rain', 'rain', 'sun',
# ...

# %%
#Predicted values
y_pred=lg.predict(X_test)
y_pred
# Out:
# array(['rain', 'rain', 'sun', 'sun', 'rain', 'rain', 'sun', 'rain', 'sun',
#        'rain', 'sun', 'rain', 'rain', 'sun', 'sun', 'rain', 'rain', 'sun',
#        'rain', 'sun', 'rain', 'sun', 'rain', 'sun', 'rain', 'rain',
#        'rain', 'rain', 'sun', 'rain', 'rain', 'rain', 'rain', 'rain',
#        'sun', 'sun', 'rain', 'rain', 'rain', 'sun', 'rain', 'rain',
#        'rain', 'rain', 'rain', 'rain', 'sun', 'sun', 'rain', 'rain',
#        'rain', 'rain', 'rain', 'sun', 'sun', 'snow', 'rain', 'sun',
#        'rain', 'sun', 'sun', 'rain', 'sun', 'rain', 'rain', 'sun', 'sun',
#        'rain', 'rain', 'rain', 'rain', 'sun', 'sun', 'sun', 'sun', 'sun',
#        'rain', 'sun', 'rain', 'rain', 'rain', 'sun', 'sun', 'rain',
#        'rain', 'sun', 'sun', 'sun', 'rain', 'sun', 'sun', 'rain', 'rain',
#        'sun', 'sun', 'sun', 'rain', 'rain', 'sun', 'sun', 'rain', 'rain',
#        'rain', 'sun', 'sun', 'sun', 'sun', 'rain', 'rain', 'rain', 'sun',
# ...

# %%
#Creating Confusion Matrix
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[ 0,  0,  0,  0,  5],
#        [ 0,  0,  0,  0,  5],
#        [ 0,  0, 76,  0,  3],
#        [ 0,  0,  4,  2,  0],
#        [ 0,  0,  0,  0, 52]])

# %%
#Output:
# 130(76+2+52) samples found
# 17(5+5+3+4) samples not found

# %%
y_test.size
# Out:
# 147

# %%
#Output:
# Percentage of samples matched: (130/147)*100 = 88.43%

# %%
import pickle

# %%
pickle.dump(lg,open('rfp.pkl','wb'))
